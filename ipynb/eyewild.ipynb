# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline

import sys
sys.path.append("../lib/")
import meme

import importlib
importlib.reload(meme)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <module 'meme' from '../lib/meme.py'>

# %%
df = pd.read_csv("../data/2019-09-10_13-40-19.csv", index_col="#timestamp")
df.head()
# Out:
#                left  right  acc_x  acc_y  acc_z  roll  pitch  yaw  event
# #timestamp
# 1568115619267  -190    149  -2284   1667 -16311    67     52   37      0
# 1568115619279  -191    149  -2279   1705 -16347    64     34   27      0
# 1568115619290  -189    155  -2240   1687 -16340    71     37   27      0
# 1568115619305  -188    158  -2216   1702 -16364    79     49    1      0
# 1568115619306  -190    152  -2192   1691 -16349    82     13   34      0

# %%
df["vh"] = df["left"] - df["right"]
df["vv"] = 0 - (df["left"] + df["right"])*0.5

# %%
plt.figure(figsize=(12, 2))
plt.plot(df["vv"])
plt.plot(df["vh"])

# %%
df_blink = meme.detect_blink(df.index, df["vv"])

plt.figure(figsize=(12, 2))
plt.plot(df["vv"])
plt.plot(df_blink["blink"]*100)
